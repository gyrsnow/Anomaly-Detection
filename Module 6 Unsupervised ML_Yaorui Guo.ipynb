# %% [markdown]
# # Module 6 -- Unsupervised Machine Learning Techniques I
# ### APAN5420: Anomaly Detection
# ### Yaorui Guo

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Module-6----Unsupervised-Machine-Learning-Techniques-I" data-toc-modified-id="Module-6----Unsupervised-Machine-Learning-Techniques-I-1">Module 6 -- Unsupervised Machine Learning Techniques I</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#APAN5420:-Anomaly-Detection" data-toc-modified-id="APAN5420:-Anomaly-Detection-1.0.1">APAN5420: Anomaly Detection</a></span></li><li><span><a href="#Yaorui-Guo" data-toc-modified-id="Yaorui-Guo-1.0.2">Yaorui Guo</a></span></li></ul></li></ul></li><li><span><a href="#About-dataset:" data-toc-modified-id="About-dataset:-2">About dataset:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Attributes-Description:" data-toc-modified-id="Attributes-Description:-2.0.1">Attributes Description:</a></span></li></ul></li></ul></li><li><span><a href="#Section-1:-Import-Data" data-toc-modified-id="Section-1:-Import-Data-3">Section 1: Import Data</a></span></li><li><span><a href="#Section-2:-Data-Preparation" data-toc-modified-id="Section-2:-Data-Preparation-4">Section 2: Data Preparation</a></span></li><li><span><a href="#Section-3:-Feature-Engineering" data-toc-modified-id="Section-3:-Feature-Engineering-5">Section 3: Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Section-3.1:--Ratio-of-average-Total-PMT--by-State-&amp;-DRG" data-toc-modified-id="Section-3.1:--Ratio-of-average-Total-PMT--by-State-&amp;-DRG-5.1">Section 3.1:  Ratio of average Total PMT  by State &amp; DRG</a></span></li><li><span><a href="#Section-3.2:-Ratio-of-median-Total-PMT--by-State-&amp;-DRG" data-toc-modified-id="Section-3.2:-Ratio-of-median-Total-PMT--by-State-&amp;-DRG-5.2">Section 3.2: Ratio of median Total PMT  by State &amp; DRG</a></span></li><li><span><a href="#Section-3.3:---Ratio-of-average-Total-PMT-by-City-&amp;-DRG" data-toc-modified-id="Section-3.3:---Ratio-of-average-Total-PMT-by-City-&amp;-DRG-5.3">Section 3.3:   Ratio of average Total PMT by City &amp; DRG</a></span></li><li><span><a href="#Section-3.4:-Ratio-of-median-Total-PMT-by-City-&amp;-DRG" data-toc-modified-id="Section-3.4:-Ratio-of-median-Total-PMT-by-City-&amp;-DRG-5.4">Section 3.4: Ratio of median Total PMT by City &amp; DRG</a></span></li><li><span><a href="#Section-3.5:---Ratio-of-average-Total_Discharges-by-State-&amp;-DRG" data-toc-modified-id="Section-3.5:---Ratio-of-average-Total_Discharges-by-State-&amp;-DRG-5.5">Section 3.5:   Ratio of average Total_Discharges by State &amp; DRG</a></span></li><li><span><a href="#Section-3.6:-Ratio-of-median-Total_Discharges-by-State-&amp;-DRG" data-toc-modified-id="Section-3.6:-Ratio-of-median-Total_Discharges-by-State-&amp;-DRG-5.6">Section 3.6: Ratio of median Total_Discharges by State &amp; DRG</a></span></li><li><span><a href="#Section-3.7:-Ratio-of-average-Covered_Charges-by-State-&amp;-DRG" data-toc-modified-id="Section-3.7:-Ratio-of-average-Covered_Charges-by-State-&amp;-DRG-5.7">Section 3.7: Ratio of average Covered_Charges by State &amp; DRG</a></span></li><li><span><a href="#Section-3.8:-Ratio-of-average-Covered_Charges-by-City-&amp;-DRG" data-toc-modified-id="Section-3.8:-Ratio-of-average-Covered_Charges-by-City-&amp;-DRG-5.8">Section 3.8: Ratio of average Covered_Charges by City &amp; DRG</a></span></li><li><span><a href="#Section-3.9:--Ratio_Average_Medicare_to_TotalPMT-by-City-&amp;-DRG" data-toc-modified-id="Section-3.9:--Ratio_Average_Medicare_to_TotalPMT-by-City-&amp;-DRG-5.9">Section 3.9:  Ratio_Average_Medicare_to_TotalPMT by City &amp; DRG</a></span></li><li><span><a href="#Section-3.10:--Ratio_Median_Medicare_to_TotalPMT-by-City-&amp;-DRG" data-toc-modified-id="Section-3.10:--Ratio_Median_Medicare_to_TotalPMT-by-City-&amp;-DRG-5.10">Section 3.10:  Ratio_Median_Medicare_to_TotalPMT by City &amp; DRG</a></span></li></ul></li><li><span><a href="#Section-4-Merged-Dataset-with-New-Features" data-toc-modified-id="Section-4-Merged-Dataset-with-New-Features-6">Section 4 Merged Dataset with New Features</a></span></li><li><span><a href="#Section-5:-Modeling" data-toc-modified-id="Section-5:-Modeling-7">Section 5: Modeling</a></span><ul class="toc-item"><li><span><a href="#Section-5.1-PCA-Meethod" data-toc-modified-id="Section-5.1-PCA-Meethod-7.1">Section 5.1 PCA Meethod</a></span></li><li><span><a href="#What-is-PCA" data-toc-modified-id="What-is-PCA-7.2">What is PCA</a></span></li></ul></li><li><span><a href="#5.1.1-PCA-from-library-scikit-learn" data-toc-modified-id="5.1.1-PCA-from-library-scikit-learn-8">5.1.1 PCA from library scikit-learn</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#It-shows-the-first-principal-component-accounts-for-33.47%-variance,-the-second,-third,-fourth-and-fifth-account-for-20.20%,-18.79%,-12.36%-and-9.13%-variance-respectively.-Approximatly-93.96%-of-the-information-is-captured-by-the-first-5-principal-components." data-toc-modified-id="It-shows-the-first-principal-component-accounts-for-33.47%-variance,-the-second,-third,-fourth-and-fifth-account-for-20.20%,-18.79%,-12.36%-and-9.13%-variance-respectively.-Approximatly-93.96%-of-the-information-is-captured-by-the-first-5-principal-components.-8.0.1">It shows the first principal component accounts for 33.47% variance, the second, third, fourth and fifth account for 20.20%, 18.79%, 12.36% and 9.13% variance respectively. Approximatly 93.96% of the information is captured by the first 5 principal components.</a></span></li><li><span><a href="#Using-pca()-to-reduce-the-dimension-of-train-set-and-calculate-the-degree-of-deviation-of-the-data-samples-in-that-direction.-So-here-y-can-be-interpreted-as-mapping-the-original-data-X-to-a-new-space.-M-is-the-deviation-matrix-of-the-data-samples-and-each-row-in-M-represents-the-distance-of-each-sample-from-each-feature-vector-in-the-reconstruction-space.-After-calculating-the-degree-of-deviation-of-the-data-samples-in-all-directions,-in-order-to-give-a-combined-anomaly-score,-the-most-natural-approach-is-to-add-up-the-deviations-of-the-samples-in-all-directions." data-toc-modified-id="Using-pca()-to-reduce-the-dimension-of-train-set-and-calculate-the-degree-of-deviation-of-the-data-samples-in-that-direction.-So-here-y-can-be-interpreted-as-mapping-the-original-data-X-to-a-new-space.-M-is-the-deviation-matrix-of-the-data-samples-and-each-row-in-M-represents-the-distance-of-each-sample-from-each-feature-vector-in-the-reconstruction-space.-After-calculating-the-degree-of-deviation-of-the-data-samples-in-all-directions,-in-order-to-give-a-combined-anomaly-score,-the-most-natural-approach-is-to-add-up-the-deviations-of-the-samples-in-all-directions.-8.0.2">Using pca() to reduce the dimension of train set and calculate the degree of deviation of the data samples in that direction. So here y can be interpreted as mapping the original data X to a new space. M is the deviation matrix of the data samples and each row in M represents the distance of each sample from each feature vector in the reconstruction space. After calculating the degree of deviation of the data samples in all directions, in order to give a combined anomaly score, the most natural approach is to add up the deviations of the samples in all directions.</a></span></li><li><span><a href="#Slice-M-and-then-perform-the-calculation-of-distance-for-each-sample-point" data-toc-modified-id="Slice-M-and-then-perform-the-calculation-of-distance-for-each-sample-point-8.0.3">Slice M and then perform the calculation of distance for each sample point</a></span></li><li><span><a href="#I-set-the-outliers_fraction-to-1%-because-in-the-case-of-the-standard-normal-distribution-we-generally-consider-data-beyond-3-standard-deviations-as-outliers,-and-data-within-3-standard-deviations-contain-more-than-99%-of-the-data-in-the-data-set,-so-the-remaining-1%-of-data-can-be-considered-as-outliers." data-toc-modified-id="I-set-the-outliers_fraction-to-1%-because-in-the-case-of-the-standard-normal-distribution-we-generally-consider-data-beyond-3-standard-deviations-as-outliers,-and-data-within-3-standard-deviations-contain-more-than-99%-of-the-data-in-the-data-set,-so-the-remaining-1%-of-data-can-be-considered-as-outliers.-8.0.4">I set the outliers_fraction to 1% because in the case of the standard normal distribution we generally consider data beyond 3 standard deviations as outliers, and data within 3 standard deviations contain more than 99% of the data in the data set, so the remaining 1% of data can be considered as outliers.</a></span></li><li><span><a href="#Threshold-calculation-is-performed-on-the-sliced-data-set,-and-if-the-score-is-greater-than-the-threshold,-it-is-considered-as-abnormal." data-toc-modified-id="Threshold-calculation-is-performed-on-the-sliced-data-set,-and-if-the-score-is-greater-than-the-threshold,-it-is-considered-as-abnormal.-8.0.5">Threshold calculation is performed on the sliced data set, and if the score is greater than the threshold, it is considered as abnormal.</a></span></li><li><span><a href="#It-identifies-1305-(1%)data-points-higher-than-the-threshold-c1-as-outliers" data-toc-modified-id="It-identifies-1305-(1%)data-points-higher-than-the-threshold-c1-as-outliers-8.0.6">It identifies 1305 (1%)data points higher than the threshold c1 as outliers</a></span></li><li><span><a href="#It-identifies-884-(2.7%)-data-points-higher-than-the-threshold-c1-as-outliers-from-test-set." data-toc-modified-id="It-identifies-884-(2.7%)-data-points-higher-than-the-threshold-c1-as-outliers-from-test-set.-8.0.7">It identifies 884 (2.7%) data points higher than the threshold c1 as outliers from test set.</a></span></li></ul></li></ul></li><li><span><a href="#5.1.2-PCA-from-library-pyOD" data-toc-modified-id="5.1.2-PCA-from-library-pyOD-9">5.1.2 PCA from library pyOD</a></span><ul class="toc-item"><li><span><a href="#As-I-mentioned-earlier,-we-can-set-the-outliers_fraction-to-1%" data-toc-modified-id="As-I-mentioned-earlier,-we-can-set-the-outliers_fraction-to-1%-9.1">As I mentioned earlier, we can set the outliers_fraction to 1%</a></span><ul class="toc-item"><li><span><a href="#When-the-outlier-score-exceeds-approximately-300,-the-PCA-model-treats-the-data-points-as-an-anomaly" data-toc-modified-id="When-the-outlier-score-exceeds-approximately-300,-the-PCA-model-treats-the-data-points-as-an-anomaly-9.1.1">When the outlier score exceeds approximately 300, the PCA model treats the data points as an anomaly</a></span></li></ul></li><li><span><a href="#I-chose-features-1-and-4-for-comparison,-the-blue-dots-represent-cluster-0-for-normal-data,-while-the-yellow-dots-are-cluster-1-for-abnormal-data." data-toc-modified-id="I-chose-features-1-and-4-for-comparison,-the-blue-dots-represent-cluster-0-for-normal-data,-while-the-yellow-dots-are-cluster-1-for-abnormal-data.-9.2">I chose features 1 and 4 for comparison, the blue dots represent cluster 0 for normal data, while the yellow dots are cluster 1 for abnormal data.</a></span></li><li><span><a href="#Section-5.2-Histogram-based-Outlier-Detection-(HBOS)-Method" data-toc-modified-id="Section-5.2-Histogram-based-Outlier-Detection-(HBOS)-Method-9.3">Section 5.2 Histogram-based Outlier Detection (HBOS) Method</a></span></li><li><span><a href="#What-is-Histogram-based-Outlier-Detection-(HBOS)" data-toc-modified-id="What-is-Histogram-based-Outlier-Detection-(HBOS)-9.4">What is Histogram-based Outlier Detection (HBOS)</a></span></li><li><span><a href="#Aggregating-Multiple-Models-for-HBOS" data-toc-modified-id="Aggregating-Multiple-Models-for-HBOS-9.5">Aggregating Multiple Models for HBOS</a></span><ul class="toc-item"><li><span><a href="#Method1:--Average" data-toc-modified-id="Method1:--Average-9.5.1">Method1:  Average</a></span></li><li><span><a href="#From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-3.-I-chose-3-as-the-cut-point,-so-I-can-suggest-those->=-3-to-be-outliers." data-toc-modified-id="From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-3.-I-chose-3-as-the-cut-point,-so-I-can-suggest-those->=-3-to-be-outliers.-9.5.2">From this histogram, we can see that most of the data points are distributed at less than 3. I chose 3 as the cut point, so I can suggest those &gt;= 3 to be outliers.</a></span></li><li><span><a href="#In-average-method-it-identifies-249-(1%)-data-points-that-have-the-outlier-scores-higher-than-3." data-toc-modified-id="In-average-method-it-identifies-249-(1%)-data-points-that-have-the-outlier-scores-higher-than-3.-9.5.3">In average method it identifies 249 (1%) data points that have the outlier scores higher than 3.</a></span></li><li><span><a href="#I-have-5-Features-here.-Suppose-a-high-value-in-each-Feature-means-abnormal.-The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-average-score-in-Cluster-0." data-toc-modified-id="I-have-5-Features-here.-Suppose-a-high-value-in-each-Feature-means-abnormal.-The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-average-score-in-Cluster-0.-9.5.4">I have 5 Features here. Suppose a high value in each Feature means abnormal. The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and average score in Cluster 0.</a></span></li><li><span><a href="#Method2:-Maximum-of-Maximum-(MOM)" data-toc-modified-id="Method2:-Maximum-of-Maximum-(MOM)-9.5.5">Method2: Maximum of Maximum (MOM)</a></span></li><li><span><a href="#From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-4.-I-chose-4-as-the-cut-point,-so-I-can-suggest-those->=-4-to-be-outliers." data-toc-modified-id="From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-4.-I-chose-4-as-the-cut-point,-so-I-can-suggest-those->=-4-to-be-outliers.-9.5.6">From this histogram, we can see that most of the data points are distributed at less than 4. I chose 4 as the cut point, so I can suggest those &gt;= 4 to be outliers.</a></span></li><li><span><a href="#In-MOM-method-it-identifies-376-(1.2%)-data-points-that-have-the-outlier-scores-higher-than-4." data-toc-modified-id="In-MOM-method-it-identifies-376-(1.2%)-data-points-that-have-the-outlier-scores-higher-than-4.-9.5.7">In MOM method it identifies 376 (1.2%) data points that have the outlier scores higher than 4.</a></span></li><li><span><a href="#The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-MOM-score-in-Cluster-0." data-toc-modified-id="The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-MOM-score-in-Cluster-0.-9.5.8">The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and MOM score in Cluster 0.</a></span></li><li><span><a href="#Method3:-Average-of-Maximum-(AOM)" data-toc-modified-id="Method3:-Average-of-Maximum-(AOM)-9.5.9">Method3: Average of Maximum (AOM)</a></span></li><li><span><a href="#From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-3.-I-chose-3-as-the-cut-point,-so-I-can-suggest-those->=-3-to-be-outliers." data-toc-modified-id="From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-3.-I-chose-3-as-the-cut-point,-so-I-can-suggest-those->=-3-to-be-outliers.-9.5.10">From this histogram, we can see that most of the data points are distributed at less than 3. I chose 3 as the cut point, so I can suggest those &gt;= 3 to be outliers.</a></span></li><li><span><a href="#In-AOM-method-it-identifies-387-(1.2%)-data-points-that-have-the-outlier-scores-higher-than-3." data-toc-modified-id="In-AOM-method-it-identifies-387-(1.2%)-data-points-that-have-the-outlier-scores-higher-than-3.-9.5.11">In AOM method it identifies 387 (1.2%) data points that have the outlier scores higher than 3.</a></span></li><li><span><a href="#The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-AOM-score-in-Cluster-0." data-toc-modified-id="The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-AOM-score-in-Cluster-0.-9.5.12">The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and AOM score in Cluster 0.</a></span></li><li><span><a href="#Method4:-Maximum-of-Average-(MOA)" data-toc-modified-id="Method4:-Maximum-of-Average-(MOA)-9.5.13">Method4: Maximum of Average (MOA)</a></span></li><li><span><a href="#From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-3.-I-chose-3-as-the-cut-point,-so-I-can-suggest-those->=-3-to-be-outliers." data-toc-modified-id="From-this-histogram,-we-can-see-that-most-of-the-data-points-are-distributed-at-less-than-3.-I-chose-3-as-the-cut-point,-so-I-can-suggest-those->=-3-to-be-outliers.-9.5.14">From this histogram, we can see that most of the data points are distributed at less than 3. I chose 3 as the cut point, so I can suggest those &gt;= 3 to be outliers.</a></span></li><li><span><a href="#In-MOA-method-it-identifies-573-(1.8%)-data-points-that-have-the-outlier-scores-higher-than-3." data-toc-modified-id="In-MOA-method-it-identifies-573-(1.8%)-data-points-that-have-the-outlier-scores-higher-than-3.-9.5.15">In MOA method it identifies 573 (1.8%) data points that have the outlier scores higher than 3.</a></span></li><li><span><a href="#The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-MOA-score-in-Cluster-0." data-toc-modified-id="The-summary-statistics-show-the-average-anomaly-score-of-Cluster-0-is-smaller-than-that-of-Cluster-1,-indicating-Cluster-1-to-be-the-anomaly-group.-The-fact-is-that-each-Feature-have-lower-means-and-MOA-score-in-Cluster-0.-9.5.16">The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and MOA score in Cluster 0.</a></span></li></ul></li></ul></li><li><span><a href="#Section-6:-Conclusion" data-toc-modified-id="Section-6:-Conclusion-10">Section 6: Conclusion</a></span><ul class="toc-item"><li><span><a href="#Business-Insight" data-toc-modified-id="Business-Insight-10.1">Business Insight</a></span></li><li><span><a href="#Limitation" data-toc-modified-id="Limitation-10.2">Limitation</a></span></li></ul></li><li><span><a href="#Section-7:-Reference" data-toc-modified-id="Section-7:-Reference-11">Section 7: Reference</a></span></li></ul></div>

# %% [markdown]
# # About dataset:
# This dataset will show you how price for the same diagnosis and the same treatment and in the same city can vary differently across different providers. Variation of hospital charges in the various hospitals in the US for the top 100 diagnoses.
#
# This dataset is owned by the U.S. government. It is available for free on data.gov, and the dataset is updated regularly here.
#
# ### Attributes Description:
# - DRG Definition: The code and description identifying the MS-DRG. MS-DRGs are a classification system that groups similar clinical conditions (diagnoses) and the procedures furnished by the hospital during the stay.
# - Provider Id: The CMS Certification Number (CCN) assigned to the Medicare certified hospital facility.
# - Provider Name: The name of the provider.
# - Provider Street Address: The provider’s street address.
# - Provider City: The city where the provider is located.
# - Provider State: The state where the provider is located.
# - Provider Zip Code: The provider’s zip code.
# - Provider HRR: The Hospital Referral Region (HRR) where the provider is located.
# - Total Discharges: The number of discharges billed by the provider for inpatient hospital services.
# - Average Covered Charges: The provider's average charge for services covered by Medicare for all discharges in the MS-DRG. These will vary from hospital to hospital because of differences in hospital charge structures.
# - Average Total Payments: The average total payments to all providers for the MS-DRG including the MSDRG amount, teaching, disproportionate share, capital, and outlier payments for all cases. Also included in average total payments are co-payment and deductible amounts that the patient is responsible for and any additional payments by third parties for coordination of benefits.
# - Average Medicare Payments: The average amount that Medicare pays to the provider for Medicare's share of the MS-DRG. Medicare payments DO NOT include beneficiary co-payments and deductible amounts nor any additional payments from third parties for coordination of benefits.

# %% [markdown]
# # Section 1: Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyod.models.hbos import HBOS
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
path = '/Users/gyr/Desktop/5420_Anomaly detection/4 Healthcare/' 
data = pd.read_csv(path + 'inpatientCharges.csv')
data.head()
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code Hospital Referral Region Description  \
# 0             AL              36301                          AL - Dothan
# ...

# %% [markdown]
# # Section 2: Data Preparation

# %%
data.isnull().sum()
# Out:
# DRG Definition                          0
# Provider Id                             0
# Provider Name                           0
# Provider Street Address                 0
# Provider City                           0
# Provider State                          0
# Provider Zip Code                       0
# Hospital Referral Region Description    0
#  Total Discharges                       0
#  Average Covered Charges                0
#  Average Total Payments                 0
# Average Medicare Payments               0
# dtype: int64

# %%
data.columns = ['DRG','Provider_Id', 'Provider_Name','Provider_StreetAddress','Provider_City',
               'Provider_State','Provider_Zipcode','Hospital_referral_region_desp',
                'Total_Discharges','Average_Covered_Charges','Average_Total_Payments',
                'Average_Medicare_Payments']
# data = data.drop('Average_Covered_Charges',axis=1)

# %%
data.head()
# Out:
#                                         DRG  Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# Distribution plots of average total payments 
data['Average_Total_Payments'].describe()
# Out:
# count       163065
# unique      147842
# top       $4370.00
# freq             9
# Name: Average_Total_Payments, dtype: object

# %%
# Change data type and transfer spending amount with dollar sign into numeric
data['DRG'] = data['DRG'].astype('category')
data['Provider_State'] = data['Provider_State'].astype('category')
data['Provider_City'] = data['Provider_City'].astype('category')
data['Provider_Id'] = data['Provider_Id'].astype('category')

var = ['Average_Covered_Charges','Average_Total_Payments','Average_Medicare_Payments']
data[var] = data[var].replace({'\$': ''}, regex=True).astype(float)

# %%
# Create a new column Average_Patients_Payments, which is the differnce betwenn Avg total pmt and avg medicare pmt 
data["Average_Patients_Payments"] = data['Average_Total_Payments'] - data['Average_Medicare_Payments']
# Create a new column Ratio_Medicare_to_TotalPMT, which is the differnce betwenn Avg total pmt and avg medicare pmt 
data["Ratio_Medicare_to_TotalPMT"] =  data['Average_Medicare_Payments']/ data['Average_Total_Payments']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163065 entries, 0 to 163064
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DRG                            163065 non-null  category
#  1   Provider_Id                    163065 non-null  category
#  2   Provider_Name                  163065 non-null  object
#  3   Provider_StreetAddress         163065 non-null  object
#  4   Provider_City                  163065 non-null  category
#  5   Provider_State                 163065 non-null  category
#  6   Provider_Zipcode               163065 non-null  int64
#  7   Hospital_referral_region_desp  163065 non-null  object
#  8   Total_Discharges               163065 non-null  int64
#  9   Average_Covered_Charges        163065 non-null  float64
#  10  Average_Total_Payments         163065 non-null  float64
#  11  Average_Medicare_Payments      163065 non-null  float64
# ...

# %%
# Z-score for anomaly values detection
df_zscore = data.iloc[:,8:13]
df_zscores = (df_zscore - df_zscore.mean())/df_zscore.std()
df_zscore[df_zscores.abs()>3].count() / data.iloc[:,8:13].count()
# Out:
# Total_Discharges             0.017110
# Average_Covered_Charges      0.019250
# Average_Total_Payments       0.025462
# Average_Medicare_Payments    0.025450
# Average_Patients_Payments    0.015761
# dtype: float64

# %% [markdown]
# - Although there are outliers in the data, the proportion of the total data is not large

# %% [markdown]
# # Section 3: Feature Engineering

# %% [markdown]
# ## Section 3.1:  Ratio of average Total PMT  by State & DRG

# %%
bm_avg_payment_st_drg = data.groupby(['Provider_State','DRG'])['Average_Total_Payments'].mean().reset_index()
bm_avg_payment_st_drg.columns = ['Provider_State','DRG','Avg_Payment_ByStateDRG']
bm_avg_payment_st_drg.head()
# Out:
#   Provider_State                                                DRG  \
# 0             AK           039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1             AK  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...
# 2             AK  064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 3             AK  065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 4             AK  066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
#
#    Avg_Payment_ByStateDRG
# 0             8401.950000
# 1             8799.000000
# 2            21608.010000
# 3            12555.548333
# 4             9275.867500

# %%
# add the new feature average spending to the dataset 
df1= pd.merge(data, bm_avg_payment_st_drg, how='left', on=['Provider_State', 'DRG'])
df1['Avg_Payment_ByStateDRG_ratio'] = np.where(df1['Avg_Payment_ByStateDRG']==0,0, 
                                               df1['Average_Total_Payments'] / df1['Avg_Payment_ByStateDRG'])
df1.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'Avg_Payment_ByStateDRG_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df1[binned_var] = pd.qcut( df1[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df1)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.384, 0.694]'),
#  Text(1, 0, '(0.694, 0.785]'),
#  Text(2, 0, '(0.785, 0.864]'),
#  Text(3, 0, '(0.864, 0.957]'),
#  Text(4, 0, '(0.957, 1.102]'),
#  Text(5, 0, '(1.102, 1.383]'),
#  Text(6, 0, '(1.383, 1.663]'),
#  Text(7, 0, '(1.663, 7.858]')]

# %%
df1[df1[var]>1.663].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1627.000000       1627.000000              1627.000000
# mean       47876.758451         36.334972             65037.922876
# std        30141.952013         36.306848             77310.116572
# min         1655.000000         11.000000              4202.180000
# 25%        20785.000000         16.000000             24503.080000
# 50%        40962.000000         25.000000             40721.710000
# 75%        77030.000000         43.000000             75474.120000
# max        98195.000000        483.000000            929118.900000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1627.000000                1627.000000
# mean             20907.369693               17848.583417
# std              17158.855043               16100.709956
# min               5886.030000                1400.570000
# 25%              11012.660000                8889.000000
# ...

# %% [markdown]
# From the histogram can see the proportion of percentile binning in 99% of the proportion of rising anomalies, I chose 1.663 as the threshold value to get 1627 data counted as anomalies

# %% [markdown]
# ## Section 3.2: Ratio of median Total PMT  by State & DRG

# %%
bm_med_payment_st_drg = data.groupby(['Provider_State','DRG'])['Average_Total_Payments'].median().reset_index()
bm_med_payment_st_drg.columns = ['Provider_State','DRG','Med_Payment_ByStateDRG']
bm_med_payment_st_drg.describe()
# Out:
#        Med_Payment_ByStateDRG
# count             5025.000000
# mean             10245.003566
# std               7833.510767
# min               3130.820000
# 25%               5380.710000
# 50%               7447.180000
# 75%              12010.045000
# max              68006.425000

# %%
df2= pd.merge(data, bm_med_payment_st_drg, how='left', on=['Provider_State', 'DRG'])
df2['Med_Payment_ByStateDRG_ratio'] = np.where(df2['Med_Payment_ByStateDRG']==0,0, 
                                               df2['Average_Total_Payments'] / df2['Med_Payment_ByStateDRG'])
df2.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'Med_Payment_ByStateDRG_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df2[binned_var] = pd.qcut(df2[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df2)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.517, 0.75]'),
#  Text(1, 0, '(0.75, 0.83]'),
#  Text(2, 0, '(0.83, 0.908]'),
#  Text(3, 0, '(0.908, 1.0]'),
#  Text(4, 0, '(1.0, 1.153]'),
#  Text(5, 0, '(1.153, 1.466]'),
#  Text(6, 0, '(1.466, 1.79]'),
#  Text(7, 0, '(1.79, 9.339]')]

# %%
df2[df2[var]>1.79].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1632.000000       1632.000000              1632.000000
# mean       43477.333333         35.892157             62096.875815
# std        30195.661138         37.025080             75123.223325
# min         1655.000000         11.000000              4202.180000
# 25%        19119.750000         16.000000             22556.835000
# 50%        33136.000000         25.000000             38538.925000
# 75%        75187.250000         42.000000             72621.895000
# max        98195.000000        483.000000            929118.900000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1632.000000                1632.000000
# mean             20730.069608               17793.856771
# std              16745.333445               15673.784680
# min               5886.030000                1400.570000
# 25%              11109.747500                9054.957500
# ...

# %% [markdown]
# Similar to the first feature, this time the median is replaced and the anomalous result also appears in the last bar, so I chose a threshold of 1.79 to get 1632 anomalous values

# %% [markdown]
# ## Section 3.3:   Ratio of average Total PMT by City & DRG

# %%
avg_payment_ct_drg = data.groupby(['Provider_City','DRG'])['Average_Total_Payments'].mean().reset_index()
avg_payment_ct_drg.columns = ['Provider_City','DRG','Avg_Payment_ByCityDRG']
avg_payment_ct_drg.describe()
# Out:
#        Avg_Payment_ByCityDRG
# count          105823.000000
# mean             9446.948753
# std              7331.672396
# min              2673.000000
# 25%              5147.845000
# 50%              7039.452500
# 75%             11022.100000
# max            156158.180000

# %%
df3= pd.merge(data, avg_payment_ct_drg, how='left', on=['Provider_City', 'DRG'])
df3['avg_payment_ct_drg_ratio'] = np.where(df3['Avg_Payment_ByCityDRG']==0,0, 
                                               df3['Average_Total_Payments'] / df3['Avg_Payment_ByCityDRG'])
df3.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'avg_payment_ct_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df3[binned_var] = pd.qcut(df3[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df3)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.237, 0.727]'),
#  Text(1, 0, '(0.727, 0.828]'),
#  Text(2, 0, '(0.828, 0.956]'),
#  Text(3, 0, '(0.956, 1.0]'),
#  Text(4, 0, '(1.0, 1.02]'),
#  Text(5, 0, '(1.02, 1.186]'),
#  Text(6, 0, '(1.186, 1.381]'),
#  Text(7, 0, '(1.381, 3.753]')]

# %%
df3[df3[var]>1.381].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1626.000000       1626.000000              1626.000000
# mean       47593.527060         42.570111             52554.346882
# std        28070.663732         39.623354             56675.597983
# min         1655.000000         11.000000              5635.710000
# 25%        21287.000000         19.000000             21691.430000
# 50%        40536.000000         30.000000             33924.995000
# 75%        75235.000000         52.000000             60521.720000
# max        99645.000000        453.000000            613926.600000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1626.000000                1626.000000
# mean             17628.013739               15174.262435
# std              14292.277140               13049.321739
# min               5101.660000                1400.570000
# 25%               9289.145000                7626.467500
# ...

# %% [markdown]
# Even within states, there are differences in health care systems, facilities, and structures between cities, so this time I broke it down to cities. The distribution of the histogram has changed significantly compared to the previous one, with a more concentrated distribution of centers. The anomalous variation still appears in 99% of the percentile, and I chose a threshold of 1.381 to get 1626 anomalies

# %% [markdown]
# ## Section 3.4: Ratio of median Total PMT by City & DRG

# %%
med_payment_ct_drg = data.groupby(['Provider_City','DRG'])['Average_Total_Payments'].median().reset_index()
med_payment_ct_drg.columns = ['Provider_City','DRG','Med_Payment_ByCityDRG']
med_payment_ct_drg.describe()
# Out:
#        Med_Payment_ByCityDRG
# count          105823.000000
# mean             9415.799000
# std              7309.696367
# min              2673.000000
# 25%              5125.775000
# 50%              7014.710000
# 75%             10988.395000
# max            156158.180000

# %%
df4= pd.merge(data, med_payment_ct_drg, how='left', on=['Provider_City', 'DRG'])
df4['med_payment_ct_drg_ratio'] = np.where(df4['Med_Payment_ByCityDRG']==0,0, 
                                               df4['Average_Total_Payments'] / df4['Med_Payment_ByCityDRG'])
df4.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'med_payment_ct_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df4[binned_var] = pd.qcut(df4[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df4)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.237, 0.735]'),
#  Text(1, 0, '(0.735, 0.853]'),
#  Text(2, 0, '(0.853, 0.982]'),
#  Text(3, 0, '(0.982, 1.0]'),
#  Text(4, 0, '(1.0, 1.019]'),
#  Text(5, 0, '(1.019, 1.212]'),
#  Text(6, 0, '(1.212, 1.499]'),
#  Text(7, 0, '(1.499, 5.592]')]

# %%
df4[df4[var]>1.499].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1634.000000       1634.000000              1634.000000
# mean       48297.697674         43.079559             51714.596787
# std        27870.854045         40.882186             55212.542844
# min         1199.000000         11.000000              5635.710000
# 25%        23298.000000         19.000000             21599.282500
# 50%        40536.000000         30.500000             34230.750000
# 75%        75235.000000         53.000000             59328.972500
# max        98195.000000        622.000000            613926.600000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1634.000000                1634.000000
# mean             17070.708849               14715.094015
# std              14075.136959               12889.553370
# min               5052.530000                1855.070000
# 25%               8932.185000                7253.347500
# ...

# %% [markdown]
# The median and mean distributions are about the same, and I chose a threshold of 1.499 to get 1634 anomalies

# %% [markdown]
# ## Section 3.5:   Ratio of average Total_Discharges by State & DRG

# %%
avg_discharges_st_drg = data.groupby(['Provider_State','DRG'])['Total_Discharges'].mean().reset_index()
avg_discharges_st_drg.columns = ['Provider_State','DRG','Avg_Discharges_ByStateDRG']
avg_discharges_st_drg.describe()
# Out:
#        Avg_Discharges_ByStateDRG
# count                5025.000000
# mean                   35.680817
# std                    27.611950
# min                    11.000000
# 25%                    20.666667
# 50%                    27.500000
# 75%                    40.083333
# max                   497.000000

# %%
df5= pd.merge(data, avg_discharges_st_drg, how='left', on=['Provider_State', 'DRG'])
df5['avg_discharges_st_drg_ratio'] = np.where(df5['Avg_Discharges_ByStateDRG']==0,0, 
                                           df5['Total_Discharges'] / df5['Avg_Discharges_ByStateDRG'])
df5.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'avg_discharges_st_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df5[binned_var] = pd.qcut(df5[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df5)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.044, 0.19]'),
#  Text(1, 0, '(0.19, 0.305]'),
#  Text(2, 0, '(0.305, 0.5]'),
#  Text(3, 0, '(0.5, 0.82]'),
#  Text(4, 0, '(0.82, 1.388]'),
#  Text(5, 0, '(1.388, 2.287]'),
#  Text(6, 0, '(2.287, 3.472]'),
#  Text(7, 0, '(3.472, 24.625]')]

# %%
df5[df5[var]>3.472].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1633.000000       1633.000000              1633.000000
# mean       46212.914881        252.371096             39503.387348
# std        26567.603771        207.135149             33426.930005
# min         1605.000000         63.000000              2536.690000
# 25%        27610.000000        136.000000             19915.590000
# 50%        40202.000000        192.000000             28985.400000
# 75%        72211.000000        281.000000             46946.010000
# max        99204.000000       3383.000000            374754.040000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1633.000000                1633.000000
# mean             10569.202474                9103.433325
# std               7944.958449                7287.436654
# min               3006.010000                1967.050000
# 25%               5742.900000                4604.480000
# ...

# %% [markdown]
# This time I focus on total discharge, so we can know that for the same DRG some discharges will be very high in the case of likely medical abuse. From the distribution chart I can find the ratio from 3 times directly to 23 times, so I chose 3.472 as the threshold to get 1633 anomalies

# %% [markdown]
# ## Section 3.6: Ratio of median Total_Discharges by State & DRG

# %%
med_discharges_st_drg = data.groupby(['Provider_State','DRG'])['Total_Discharges'].median().reset_index()
med_discharges_st_drg.columns = ['Provider_State','DRG','Med_Discharges_ByStateDRG']
med_discharges_st_drg.describe()
# Out:
#        Med_Discharges_ByStateDRG
# count                5025.000000
# mean                   29.149353
# std                    22.842060
# min                    11.000000
# 25%                    18.000000
# 50%                    23.000000
# 75%                    32.000000
# max                   529.000000

# %%
df6= pd.merge(data,med_discharges_st_drg, how='left', on=['Provider_State', 'DRG'])
df6['med_discharges_st_drg_ratio'] = np.where(df6['Med_Discharges_ByStateDRG']==0,0, 
                                           df6['Total_Discharges'] / df6['Med_Discharges_ByStateDRG'])
df6.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'med_discharges_st_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df6[binned_var] = pd.qcut(df6[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df6)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.0462, 0.25]'),
#  Text(1, 0, '(0.25, 0.394]'),
#  Text(2, 0, '(0.394, 0.629]'),
#  Text(3, 0, '(0.629, 1.0]'),
#  Text(4, 0, '(1.0, 1.708]'),
#  Text(5, 0, '(1.708, 2.967]'),
#  Text(6, 0, '(2.967, 4.816]'),
#  Text(7, 0, '(4.816, 71.409]')]

# %%
df6[df6[var]>4.816].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1631.000000       1631.000000              1631.000000
# mean       45218.377682        264.871858             37569.466983
# std        26076.064881        209.042776             29856.657599
# min         1199.000000         65.000000              2536.690000
# 25%        27401.000000        142.500000             19444.525000
# 50%        40202.000000        200.000000             28398.560000
# 75%        71103.000000        300.500000             45400.665000
# max        99204.000000       3383.000000            374754.040000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1631.000000                1631.000000
# mean             10611.905788                9117.650834
# std               7529.566348                6839.912623
# min               2728.690000                1752.350000
# 25%               5889.730000                4799.315000
# ...

# %% [markdown]
# The median is not disturbed by outliers, so the 99% percentile distribution boost is even more surprising, I chose 4.816 as the threshold and got 1631 anomalies.

# %% [markdown]
# ## Section 3.7: Ratio of average Covered_Charges by State & DRG

# %%
avg_covered_charge_st_drg = data.groupby(['Provider_State','DRG'])['Average_Covered_Charges'].mean().reset_index()
avg_covered_charge_st_drg.columns = ['Provider_State','DRG','Avg_CoveredCharge_ByStateDRG']
avg_covered_charge_st_drg.describe()
# Out:
#        Avg_CoveredCharge_ByStateDRG
# count                   5025.000000
# mean                   34950.866952
# std                    28839.099439
# min                     5624.207750
# 25%                    16886.577500
# 50%                    25015.496941
# 75%                    42379.612083
# max                   277004.642419

# %%
df7= pd.merge(data, avg_covered_charge_st_drg, how='left', on=['Provider_State', 'DRG'])
df7['avg_covered_charge_st_drg_ratio'] = np.where(df7['Avg_CoveredCharge_ByStateDRG']==0,0, 
                                           df7['Average_Covered_Charges'] / df7['Avg_CoveredCharge_ByStateDRG'])
df7.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'avg_covered_charge_st_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df7[binned_var] = pd.qcut(df7[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df7)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.11, 0.362]'),
#  Text(1, 0, '(0.362, 0.503]'),
#  Text(2, 0, '(0.503, 0.704]'),
#  Text(3, 0, '(0.704, 0.943]'),
#  Text(4, 0, '(0.943, 1.254]'),
#  Text(5, 0, '(1.254, 1.68]'),
#  Text(6, 0, '(1.68, 2.211]'),
#  Text(7, 0, '(2.211, 5.795]')]

# %%
df7[df7[var]>2.211].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1629.000000       1629.000000              1629.000000
# mean       35448.060773         44.375691             99730.680645
# std        27085.813855         48.033645             86799.909728
# min         1655.000000         11.000000             19528.570000
# 25%        19013.000000         17.000000             49426.880000
# 50%        23847.000000         28.000000             75907.030000
# 75%        46206.000000         53.000000            117246.420000
# max        98122.000000        530.000000            929118.900000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1629.000000                1629.000000
# mean             13545.586992               12100.357710
# std              13894.227480               13374.365632
# min               2827.340000                1815.300000
# 25%               6238.710000                5108.860000
# ...

# %% [markdown]
# The feature variable I chose was average Covered Charges this time, and I looked for anomalies by comparing the proportional size between the same states. The histogram shows that the proportional increase of anomalies appears in 99% percentile, and I chose the threshold 2.211 to get 1629 anomalies

# %% [markdown]
# ## Section 3.8: Ratio of average Covered_Charges by City & DRG

# %%
med_covered_charge_ct_drg = data.groupby(['Provider_City','DRG'])['Average_Covered_Charges'].median().reset_index()
med_covered_charge_ct_drg.columns = ['Provider_City','DRG','Med_CoveredCharge_ByCityDRG']
med_covered_charge_ct_drg.describe()
# Out:
#        Med_CoveredCharge_ByCityDRG
# count                105823.000000
# mean                  35432.738158
# std                   34293.124445
# min                    2459.400000
# 25%                   15703.155000
# 50%                   24634.000000
# 75%                   42554.985000
# max                  929118.900000

# %%
df8= pd.merge(data, med_covered_charge_ct_drg, how='left', on=['Provider_City', 'DRG'])
df8['med_covered_charge_ct_drg_ratio'] = np.where(df8['Med_CoveredCharge_ByCityDRG']==0,0, 
                                           df8['Average_Covered_Charges'] / df8['Med_CoveredCharge_ByCityDRG'])
df8.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'med_covered_charge_ct_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df8[binned_var] = pd.qcut(df8[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df8)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.111, 0.467]'),
#  Text(1, 0, '(0.467, 0.678]'),
#  Text(2, 0, '(0.678, 0.955]'),
#  Text(3, 0, '(0.955, 1.0]'),
#  Text(4, 0, '(1.0, 1.045]'),
#  Text(5, 0, '(1.045, 1.403]'),
#  Text(6, 0, '(1.403, 2.006]'),
#  Text(7, 0, '(2.006, 7.607]')]

# %%
df8[df8[var]>2.006].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1631.000000       1631.000000              1631.000000
# mean       39814.649908         56.315144             76491.311288
# std        29924.355890         66.104342             65983.061073
# min         1655.000000         11.000000             11963.610000
# 25%        15213.000000         20.000000             39104.180000
# 50%        30342.000000         34.000000             56109.680000
# 75%        68131.000000         68.000000             88741.605000
# max        99204.000000        903.000000            613926.600000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1631.000000                1631.000000
# mean             12964.461343               11584.104862
# std              12168.891966               11605.991633
# min               2827.340000                1815.300000
# 25%               6219.535000                5136.685000
# ...

# %% [markdown]
# Similarly, this time I switched to the city breakdown. The percentage of anomalies is more evident in the last distribution, where I chose a threshold of 2.006 to get 1631 anomalies

# %% [markdown]
# ## Section 3.9:  Ratio_Average_Medicare_to_TotalPMT by City & DRG

# %%
avg_medicare_PMT_ct_drg = data.groupby(['Provider_City','DRG'])['Ratio_Medicare_to_TotalPMT'].mean().reset_index()
avg_medicare_PMT_ct_drg.columns = ['Provider_City','DRG','Avg_Medicare_PMT_ByCityDRG']
avg_medicare_PMT_ct_drg.describe()
# Out:
#        Avg_Medicare_PMT_ByCityDRG
# count               105823.000000
# mean                     0.845084
# std                      0.084464
# min                      0.043155
# 25%                      0.795571
# 50%                      0.856713
# 75%                      0.909640
# max                      1.000000

# %%
df9= pd.merge(data, avg_medicare_PMT_ct_drg, how='left', on=['Provider_City', 'DRG'])
df9['avg_medicare_PMT_ct_drg_ratio'] = np.where(df9['Avg_Medicare_PMT_ByCityDRG']==0,0, 
                                           df9['Ratio_Medicare_to_TotalPMT'] / df9['Avg_Medicare_PMT_ByCityDRG'])
df9.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'avg_medicare_PMT_ct_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df9[binned_var] = pd.qcut(df9[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df9)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.213, 0.831]'),
#  Text(1, 0, '(0.831, 0.929]'),
#  Text(2, 0, '(0.929, 0.992]'),
#  Text(3, 0, '(0.992, 1.0]'),
#  Text(4, 0, '(1.0, 1.014]'),
#  Text(5, 0, '(1.014, 1.069]'),
#  Text(6, 0, '(1.069, 1.134]'),
#  Text(7, 0, '(1.134, 1.786]')]

# %%
df9[df9[var]>1.134].describe()
# Out:
#        Provider_Zipcode  Total_Discharges  Average_Covered_Charges  \
# count       1638.000000       1638.000000              1638.000000
# mean       53437.010379         32.291209             35426.580855
# std        27308.514314         30.389350             32382.077153
# min         1069.000000         11.000000              4355.700000
# 25%        32331.250000         15.000000             15778.902500
# 50%        54453.000000         23.000000             24594.460000
# 75%        77048.000000         39.000000             42570.287500
# max        99519.000000        514.000000            289008.330000
#
#        Average_Total_Payments  Average_Medicare_Payments  \
# count             1638.000000                1638.000000
# mean              9210.646569                8253.501685
# std               6600.207015                6465.356108
# min               2951.110000                1872.610000
# 25%               5215.200000                4316.930000
# ...

# %% [markdown]
# Similar to the 9th variable, but this time I break it down to between cities. The frequency distribution graph changes, with the distribution more concentrated between 0.99 and 1. I chose 1.134 as the threshold to get 1638 anomalies

# %% [markdown]
# ## Section 3.10:  Ratio_Median_Medicare_to_TotalPMT by City & DRG

# %%
med_medicare_PMT_ct_drg = data.groupby(['Provider_City','DRG'])['Ratio_Medicare_to_TotalPMT'].median().reset_index()
med_medicare_PMT_ct_drg.columns = ['Provider_City','DRG','Med_Medicare_PMT_ByCityDRG']
med_medicare_PMT_ct_drg.describe()
# Out:
#        Med_Medicare_PMT_ByCityDRG
# count               105823.000000
# mean                     0.845952
# std                      0.084623
# min                      0.043155
# 25%                      0.796327
# 50%                      0.857648
# 75%                      0.910800
# max                      1.000000

# %%
df10= pd.merge(data, med_medicare_PMT_ct_drg, how='left', on=['Provider_City', 'DRG'])
df10['med_medicare_PMT_ct_drg_ratio'] = np.where(df10['Med_Medicare_PMT_ByCityDRG']==0,0, 
                                           df10['Ratio_Medicare_to_TotalPMT'] / df10['Med_Medicare_PMT_ByCityDRG'])
df10.head()
# Out:
#                                         DRG Provider_Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       10016
#
#                       Provider_Name      Provider_StreetAddress Provider_City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider_State  Provider_Zipcode Hospital_referral_region_desp  \
# 0             AL             36301                   AL - Dothan
# ...

# %%
# cut by percentile for plotting
var = 'med_medicare_PMT_ct_drg_ratio'
binned_var = var + '_D'
percentile = [0,0.01,0.05,0.2,0.5,0.8,0.95,0.99,1]
df10[binned_var] = pd.qcut(df10[var],percentile)

# %%
plt.figure(figsize=(6,4))
g = sns.countplot(x=binned_var, data=df10)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '(0.213, 0.813]'),
#  Text(1, 0, '(0.813, 0.924]'),
#  Text(2, 0, '(0.924, 0.993]'),
#  Text(3, 0, '(0.993, 1.0]'),
#  Text(4, 0, '(1.0, 1.006]'),
#  Text(5, 0, '(1.006, 1.058]'),
#  Text(6, 0, '(1.058, 1.128]'),
#  Text(7, 0, '(1.128, 1.87]')]

# %% [markdown]
# # Section 4 Merged Dataset with New Features

# %%
df_merged = data.merge(df1['Avg_Payment_ByStateDRG_ratio'], how='left', left_index=True, right_index=True).\
                merge(df2['Med_Payment_ByStateDRG_ratio'], how='left', left_index=True, right_index=True).\
                merge(df3['avg_payment_ct_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df4['med_payment_ct_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df5['avg_discharges_st_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df6['med_discharges_st_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df7['avg_covered_charge_st_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df8['med_covered_charge_ct_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df9['avg_medicare_PMT_ct_drg_ratio'], how='left', left_index=True, right_index=True).\
                merge(df10['med_medicare_PMT_ct_drg_ratio'],how='left', left_index=True, right_index=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163065 entries, 0 to 163064
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   DRG                              163065 non-null  category
#  1   Provider_Id                      163065 non-null  category
#  2   Provider_Name                    163065 non-null  object
#  3   Provider_StreetAddress           163065 non-null  object
#  4   Provider_City                    163065 non-null  category
#  5   Provider_State                   163065 non-null  category
#  6   Provider_Zipcode                 163065 non-null  int64
#  7   Hospital_referral_region_desp    163065 non-null  object
#  8   Total_Discharges                 163065 non-null  int64
#  9   Average_Covered_Charges          163065 non-null  float64
#  10  Average_Total_Payments           163065 non-null  float64
# ...

# %%
# Select the column included 10 features
d = df_merged.iloc[:,14:]
d.info()
# # Random sampling to reduce the file size. I choose to use 10% of sample from entire dataset.
# ds = d.sample(frac = 0.8,random_state = 1024, axis =0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163065 entries, 0 to 163064
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Avg_Payment_ByStateDRG_ratio     163065 non-null  float64
#  1   Med_Payment_ByStateDRG_ratio     163065 non-null  float64
#  2   avg_payment_ct_drg_ratio         163065 non-null  float64
#  3   med_payment_ct_drg_ratio         163065 non-null  float64
#  4   avg_discharges_st_drg_ratio      163065 non-null  float64
#  5   med_discharges_st_drg_ratio      163065 non-null  float64
#  6   avg_covered_charge_st_drg_ratio  163065 non-null  float64
#  7   med_covered_charge_ct_drg_ratio  163065 non-null  float64
#  8   avg_medicare_PMT_ct_drg_ratio    163065 non-null  float64
#  9   med_medicare_PMT_ct_drg_ratio    163065 non-null  float64
# dtypes: float64(10)
# memory usage: 12.4 MB

# %%
# data split
from sklearn.model_selection import train_test_split 
X_train, X_test= train_test_split(d, train_size=.8,random_state = 0)

print ('Original dataset characteristics：',d.shape, 
       '\nTrain dataset characteristics：',X_train.shape,
      '\nTest dataset characteristics：',X_test.shape)
# Out:
# Original dataset characteristics： (163065, 10)
# Train dataset characteristics： (130452, 10)
# Test dataset characteristics： (32613, 10)

# %%
# # Feature Scaling (Standardize data)
from pyod.utils.utility import standardizer
# X_train_norm, X_test_norm = standardizer(X_train, X_test)
X_train_norm = StandardScaler().fit_transform(X_train)
X_test_norm = StandardScaler().fit_transform(X_test)

# %% [markdown]
# # Section 5: Modeling

# %% [markdown]
# ## Section 5.1 PCA Meethod

# %% [markdown]
# ## What is PCA
# Principal component analysis (PCA) for outlier detection leverages the PCA dimensionality reduction technique, where the key point to note is that eigenvectors with larger eigenvalues represent the hyperplane where the majority of a dataset's variance lies. The premise of this outlier detection methodology is that data points with larger Euclidean distances to the mean of the data points in that principal component are anomalous.

# %% [markdown]
# # 5.1.1 PCA from library scikit-learn

# %% [markdown]
# Train set

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(X_train_norm)
# Out:
# PCA()

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.33474644, 0.20203318, 0.18792033, 0.12364743, 0.09125342,
#        0.04390711, 0.00583961, 0.00565062, 0.00379551, 0.00120637])

# %%
var_tab = pd.DataFrame({'variance':explained_variance})
var_tab['num_features'] = list(range(10))

ax = sns.barplot(y = 'variance',x = 'num_features', data = var_tab, color = 'tomato')
plt.show()

# %% [markdown]
# ### It shows the first principal component accounts for 33.47% variance, the second, third, fourth and fifth account for 20.20%, 18.79%, 12.36% and 9.13% variance respectively. Approximatly 93.96% of the information is captured by the first 5 principal components.

# %%
for i in range(len(d.columns)+1):
    print ("Explained variance by first ", i, " terms: ", sum(pca.explained_variance_ratio_[:i]))
# Out:
# Explained variance by first  0  terms:  0
# Explained variance by first  1  terms:  0.3347464383921598
# Explained variance by first  2  terms:  0.5367796133927696
# Explained variance by first  3  terms:  0.7246999393957688
# Explained variance by first  4  terms:  0.8483473647036232
# Explained variance by first  5  terms:  0.9396007809513807
# Explained variance by first  6  terms:  0.983507887778225
# Explained variance by first  7  terms:  0.9893475025926242
# Explained variance by first  8  terms:  0.9949981231966556
# Explained variance by first  9  terms:  0.9987936324235696
# Explained variance by first  10  terms:  1.0000000000000002

# %% [markdown]
# ### Using pca() to reduce the dimension of train set and calculate the degree of deviation of the data samples in that direction. So here y can be interpreted as mapping the original data X to a new space. M is the deviation matrix of the data samples and each row in M represents the distance of each sample from each feature vector in the reconstruction space. After calculating the degree of deviation of the data samples in all directions, in order to give a combined anomaly score, the most natural approach is to add up the deviations of the samples in all directions.

# %%
transformed_data = pca.fit_transform(X_train)
y = transformed_data
lambdas = pca.singular_values_
M = ((y*y)/lambdas)

# %% [markdown]
# ### Slice M and then perform the calculation of distance for each sample point

# %%
q = 5
major_components = M[:,range(q)]
major_components = np.sum(major_components, axis=1)

# %% [markdown]
# ### I set the outliers_fraction to 1% because in the case of the standard normal distribution we generally consider data beyond 3 standard deviations as outliers, and data within 3 standard deviations contain more than 99% of the data in the data set, so the remaining 1% of data can be considered as outliers.

# %%
components = pd.DataFrame({'major_components': major_components})
c1 = components.quantile(0.99)['major_components']

# %% [markdown]
# ### Threshold calculation is performed on the sliced data set, and if the score is greater than the threshold, it is considered as abnormal.

# %%
components['cluster'] = np.where(components['major_components'] < c1, 0, 1)
components['cluster'].value_counts()
# Out:
# 0    129147
# 1      1305
# Name: cluster, dtype: int64

# %%
components['cluster'].value_counts(normalize = True)
# Out:
# 0    0.989996
# 1    0.010004
# Name: cluster, dtype: float64

# %% [markdown]
# ### It identifies 1305 (1%)data points higher than the threshold c1 as outliers

# %% [markdown]
# Test set

# %%
transformed_data_test = pca.fit_transform(X_test)
y_test = transformed_data_test
lambdas_test = pca.singular_values_
M_test = ((y_test*y_test)/lambdas_test)

# %%
major_components_test = M_test[:,range(q)]
major_components_test = np.sum(major_components_test, axis=1)

# %%
components = pd.DataFrame({'major_components_test': major_components_test})
components['cluster_test'] = np.where(components['major_components_test']< c1, 0, 1)
components['cluster_test'].value_counts()
# Out:
# 0    31729
# 1      884
# Name: cluster_test, dtype: int64

# %%
components['cluster_test'].value_counts(normalize = True)
# Out:
# 0    0.972894
# 1    0.027106
# Name: cluster_test, dtype: float64

# %% [markdown]
# ### It identifies 884 (2.7%) data points higher than the threshold c1 as outliers from test set.

# %% [markdown]
# # 5.1.2 PCA from library pyOD

# %%
# PyOD
from pyod.models.pca import PCA
from pyod.utils.data import generate_data
from pyod.utils.data import evaluate_print
from pyod.utils.example import visualize
import matplotlib.pyplot as plt
from pyod.models.combination import aom, moa, average, maximization
from pyod.utils.utility import standardizer
from pyod.utils.data import generate_data, get_outliers_inliers

# %% [markdown]
# ## As I mentioned earlier, we can set the outliers_fraction to 1%

# %%
clf_name = 'PCA'
clf = PCA(n_components= 5,contamination=0.01)
clf.fit(X_train_norm)
# Out:
# PCA(contamination=0.01, copy=True, iterated_power='auto', n_components=5,
#   n_selected_components=None, random_state=None, standardization=True,
#   svd_solver='auto', tol=0.0, weighted=True, whiten=False)

# %%
clf.explained_variance_ratio_
# Out:
# array([0.33474644, 0.20203318, 0.18792033, 0.12364743, 0.09125342])

# %%
# get the prediction labels and outlier scores of the training data
y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliers)
y_train_scores = clf.decision_scores_  # raw outlier scores

# %%
train_pred_tab = pd.DataFrame({'scores': y_train_scores,'pred':y_train_pred})
train_pred_tab[train_pred_tab.pred == 1].describe()
# Out:
#             scores    pred
# count  1305.000000  1305.0
# mean    409.436818     1.0
# std     148.696235     0.0
# min     306.881396     1.0
# 25%     330.761615     1.0
# 50%     363.738190     1.0
# 75%     433.579304     1.0
# max    2511.225738     1.0

# %%
# get the prediction on the test data
y_test_pred = clf.predict(X_test_norm)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test_norm)  # outlier scores

# %%
test_pred_tab = pd.DataFrame({'scores': y_test_scores,'pred':y_test_pred})
test_pred_tab[test_pred_tab.pred == 1].describe()
# Out:
#             scores   pred
# count   319.000000  319.0
# mean    408.104644    1.0
# std     170.778161    0.0
# min     306.961984    1.0
# 25%     329.604078    1.0
# 50%     361.195923    1.0
# 75%     421.275153    1.0
# max    1863.021515    1.0

# %%
plt.hist(y_test_scores, bins='auto')

x_major_locator=MultipleLocator(50)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(0,600)
plt.grid()
plt.show()

# %% [markdown]
# ### When the outlier score exceeds approximately 300, the PCA model treats the data points as an anomaly

# %%
#Standardize score
y_test_scores = np.array(list(y_test_scores)).reshape(-1,1)
y_test_scores_norm = StandardScaler().fit_transform(y_test_scores)

import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
plt.hist(y_test_scores_norm, bins='auto') # arguments are passed to np.histogram
plt.title("Combination by average")

x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,7)
plt.grid()
plt.show()

# %%
y_test_scores_norm = list(np.array(y_test_scores_norm).flatten())
a = pd.DataFrame(X_test_norm)
a['score'] = y_test_scores_norm
a['y'] = y_test_pred

sns.scatterplot(x=2, y=4, hue=y_test_pred, data=a, palette='RdBu_r')
plt.title('Anomaly Cluster by PCA')
x_major_locator=MultipleLocator(5)
y_major_locator=MultipleLocator(2)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,30)
ax.yaxis.set_major_locator(y_major_locator)
plt.ylim(-2,15)
plt.show()

# %%
sns.scatterplot(x=2, y=4, hue=y_test_scores_norm, data=a, palette='RdBu_r')
plt.title('Anomaly Scores by PCA')
x_major_locator=MultipleLocator(5)
y_major_locator=MultipleLocator(2)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,30)
ax.yaxis.set_major_locator(y_major_locator)
plt.ylim(-2,15)
plt.show()

# %% [markdown]
# ## I chose features 1 and 4 for comparison, the blue dots represent cluster 0 for normal data, while the yellow dots are cluster 1 for abnormal data.

# %% [markdown]
# ## Section 5.2 Histogram-based Outlier Detection (HBOS) Method

# %% [markdown]
# ## What is Histogram-based Outlier Detection (HBOS)
# HBOS is an efficient unsupervised method to detect anomalies. HBOS assumes the feature independence and calculates the degree of anomalies by building histograms. In multivariate anomaly detection, a histogram for each single feature can be computed, scored individually and combined at the end.

# %%
# data split
from sklearn.model_selection import train_test_split 
X_train, X_test= train_test_split(d, train_size=.8,random_state = 0)

print ('Original dataset characteristics：',d.shape, 
       '\nTrain dataset characteristics：',X_train.shape,
      '\nTest dataset characteristics：',X_test.shape)

# Feature Scaling (Standardize data)
from pyod.utils.utility import standardizer
# X_train_norm, X_test_norm = standardizer(X_train, X_test)
X_train_norm = StandardScaler().fit_transform(X_train)
X_test_norm = StandardScaler().fit_transform(X_test)
# Out:
# Original dataset characteristics： (163065, 10)
# Train dataset characteristics： (130452, 10)
# Test dataset characteristics： (32613, 10)

# %%
# Select the column included 8 features since the last two FEATURES since incorrect clustering (cluster 0 has a higher score than cluster 1)
X_train = X_train.iloc[:,0:8]
X_test = X_test.iloc[:,0:8]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyod.models.combination import aom, moa, average, maximization
from pyod.utils.utility import standardizer

# Standardize data
X_train_norm, X_test_norm = standardizer(X_train, X_test)
# Test a range of bins
n_clf = 10
k_list = [5,10,20,25,30,35,40,45,50,100]
# Just prepare data frames so we can store the model results
train_scores = np.zeros([X_train.shape[0], n_clf])
test_scores = np.zeros([X_test.shape[0], n_clf])
train_scores.shape
# Modeling
for i in range(n_clf):
    k = k_list[i]
    hbos = HBOS(n_bins=k)
    hbos.fit(X_train_norm)

    # Store the results in each column:
    train_scores[:, i] = hbos.decision_scores_
    test_scores[:, i] = hbos.decision_function(X_test_norm) 
# Decision scores have to be normalized before combination
train_scores_norm, test_scores_norm = standardizer(train_scores,test_scores)

# %% [markdown]
# ## Aggregating Multiple Models for HBOS

# %% [markdown]
# ### Method1:  Average

# %%
# Combination by average
# The "average" function will take the average of the 8 columns. The result "y_by_average" is a single column: 
y_by_average = average(test_scores_norm)
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
plt.hist(y_by_average, bins='auto') # arguments are passed to np.histogram
plt.title("Combination by average")

x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,7)
plt.grid()
plt.show()

# %% [markdown]
# ### From this histogram, we can see that most of the data points are distributed at less than 3. I chose 3 as the cut point, so I can suggest those >= 3 to be outliers.

# %%
df_test = pd.DataFrame(X_test)
df_test['y_by_average_score'] = y_by_average
df_test['y_by_average_cluster'] = np.where(df_test['y_by_average_score']<3, 0, 1)
df_test['y_by_average_cluster'].value_counts()
# Out:
# 0    32364
# 1      249
# Name: y_by_average_cluster, dtype: int64

# %%
df_test['y_by_average_cluster'].value_counts(normalize = True)
# Out:
# 0    0.992365
# 1    0.007635
# Name: y_by_average_cluster, dtype: float64

# %% [markdown]
# ### In average method it identifies 249 (1%) data points that have the outlier scores higher than 3.

# %%
df_test.groupby("y_by_average_cluster").mean()
# Out:
#                       Avg_Payment_ByStateDRG_ratio  \
# y_by_average_cluster
# 0                                         0.994172
# 1                                         1.636794
#
#                       Med_Payment_ByStateDRG_ratio  avg_payment_ct_drg_ratio  \
# y_by_average_cluster
# 0                                         1.044556                  0.996597
# 1                                         1.749665                  1.375865
#
#                       med_payment_ct_drg_ratio  avg_discharges_st_drg_ratio  \
# y_by_average_cluster
# 0                                     1.006726                     0.992012
# 1                                     1.486352                     1.868499
#
#                       med_discharges_st_drg_ratio  \
# y_by_average_cluster
# 0                                        1.249822
# 1                                        2.432070
#
#                       avg_covered_charge_st_drg_ratio  \
# y_by_average_cluster
# ...

# %% [markdown]
# ### I have 5 Features here. Suppose a high value in each Feature means abnormal. The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and average score in Cluster 0.

# %% [markdown]
# ### Method2: Maximum of Maximum (MOM)

# %%
# Combination by mom
y_by_maximization = maximization(test_scores_norm)
             
import matplotlib.pyplot as plt
plt.hist(y_by_maximization, bins='auto')  # arguments are passed to np.histogram
plt.title("Combination by max")

x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,7)
plt.grid()
plt.show()

# %% [markdown]
# ### From this histogram, we can see that most of the data points are distributed at less than 4. I chose 4 as the cut point, so I can suggest those >= 4 to be outliers.

# %%
df_test = pd.DataFrame(X_test)
df_test['y_by_maximization_score'] = y_by_maximization
df_test['y_by_maximization_cluster'] = np.where(df_test['y_by_maximization_score']<4, 0, 1)
df_test['y_by_maximization_cluster'].value_counts()
# Out:
# 0    32237
# 1      376
# Name: y_by_maximization_cluster, dtype: int64

# %%
df_test['y_by_maximization_cluster'].value_counts(normalize = True)
# Out:
# 0    0.988471
# 1    0.011529
# Name: y_by_maximization_cluster, dtype: float64

# %% [markdown]
# ### In MOM method it identifies 376 (1.2%) data points that have the outlier scores higher than 4.

# %%
df_test.groupby("y_by_maximization_cluster").mean()
# Out:
#                            Avg_Payment_ByStateDRG_ratio  \
# y_by_maximization_cluster
# 0                                              0.993280
# 1                                              1.496209
#
#                            Med_Payment_ByStateDRG_ratio  \
# y_by_maximization_cluster
# 0                                              1.043572
# 1                                              1.595885
#
#                            avg_payment_ct_drg_ratio  med_payment_ct_drg_ratio  \
# y_by_maximization_cluster
# 0                                          0.996394                  1.006414
# 1                                          1.265177                  1.351123
#
#                            avg_discharges_st_drg_ratio  \
# y_by_maximization_cluster
# 0                                             0.992051
# 1                                             1.569131
#
#                            med_discharges_st_drg_ratio  \
# y_by_maximization_cluster
# ...

# %% [markdown]
# ### The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and MOM score in Cluster 0.

# %% [markdown]
# ### Method3: Average of Maximum (AOM)

# %%
# Combination by aom
y_by_aom = aom(test_scores_norm, n_buckets=5)
             
import matplotlib.pyplot as plt
plt.hist(y_by_aom, bins='auto')  # arguments are passed to np.histogram
plt.title("Average of Maximum")

x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,7)
plt.grid()
plt.show()

# %% [markdown]
# ### From this histogram, we can see that most of the data points are distributed at less than 3. I chose 3 as the cut point, so I can suggest those >= 3 to be outliers.

# %%
df_test = pd.DataFrame(X_test)
df_test['y_by_aom_score'] = y_by_aom
df_test['y_by_aom_cluster'] = np.where(df_test['y_by_aom_score']<3, 0, 1)
df_test['y_by_aom_cluster'].value_counts()
# Out:
# 0    32226
# 1      387
# Name: y_by_aom_cluster, dtype: int64

# %%
df_test['y_by_aom_cluster'].value_counts(normalize = True)
# Out:
# 0    0.988134
# 1    0.011866
# Name: y_by_aom_cluster, dtype: float64

# %% [markdown]
# ### In AOM method it identifies 387 (1.2%) data points that have the outlier scores higher than 3.

# %%
df_test.groupby("y_by_aom_cluster").mean()
# Out:
#                   Avg_Payment_ByStateDRG_ratio  Med_Payment_ByStateDRG_ratio  \
# y_by_aom_cluster
# 0                                     0.992072                      1.042290
# 1                                     1.582475                      1.686902
#
#                   avg_payment_ct_drg_ratio  med_payment_ct_drg_ratio  \
# y_by_aom_cluster
# 0                                 0.995448                  1.005344
# 1                                 1.336303                  1.430420
#
#                   avg_discharges_st_drg_ratio  med_discharges_st_drg_ratio  \
# y_by_aom_cluster
# 0                                    0.988855                     1.245593
# 1                                    1.818875                     2.362687
#
#                   avg_covered_charge_st_drg_ratio  \
# y_by_aom_cluster
# 0                                        0.988931
# 1                                        1.814341
#
# ...

# %% [markdown]
# ### The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and AOM score in Cluster 0.

# %% [markdown]
# ### Method4: Maximum of Average (MOA)

# %%
# Combination by moa
y_by_moa = moa(test_scores_norm, n_buckets=5)

import matplotlib.pyplot as plt
plt.hist(y_by_moa, bins='auto')  # arguments are passed to np.histogram
plt.title("Maximum of Average")

x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-2,7)
plt.grid()
plt.show()

# %% [markdown]
# ### From this histogram, we can see that most of the data points are distributed at less than 3. I chose 3 as the cut point, so I can suggest those >= 3 to be outliers.

# %%
df_test = pd.DataFrame(X_test)
df_test['y_by_moa_score'] = y_by_moa
df_test['y_by_moa_cluster'] = np.where(df_test['y_by_moa_score']< 3, 0, 1)
df_test['y_by_moa_cluster'].value_counts()
# Out:
# 0    32040
# 1      573
# Name: y_by_moa_cluster, dtype: int64

# %%
df_test['y_by_moa_cluster'].value_counts(normalize = True)
# Out:
# 0    0.98243
# 1    0.01757
# Name: y_by_moa_cluster, dtype: float64

# %% [markdown]
# ### In MOA method it identifies 573 (1.8%) data points that have the outlier scores higher than 3.

# %%
df_test.groupby("y_by_moa_cluster").mean()
# Out:
#                   Avg_Payment_ByStateDRG_ratio  Med_Payment_ByStateDRG_ratio  \
# y_by_moa_cluster
# 0                                     0.989743                      1.039731
# 1                                     1.521075                      1.620733
#
#                   avg_payment_ct_drg_ratio  med_payment_ct_drg_ratio  \
# y_by_moa_cluster
# 0                                 0.994497                  1.004172
# 1                                 1.278876                  1.357983
#
#                   avg_discharges_st_drg_ratio  med_discharges_st_drg_ratio  \
# y_by_moa_cluster
# 0                                    0.985816                     1.239942
# 1                                    1.719379                     2.316070
#
#                   avg_covered_charge_st_drg_ratio  \
# y_by_moa_cluster
# 0                                        0.984589
# 1                                        1.789190
#
# ...

# %% [markdown]
# ### The summary statistics show the average anomaly score of Cluster 0 is smaller than that of Cluster 1, indicating Cluster 1 to be the anomaly group. The fact is that each Feature have lower means and MOA score in Cluster 0.

# %% [markdown]
# # Section 6: Conclusion

# %% [markdown]
# ## Business Insight
# - Both PCA and HBOS are very efficient models in detecting anomalies, and we can focus more on those anomalies that could be potential medical abuse, waste or fraud.
#
# - Feature selection is important for model construction, when poor features are added there will be some impact on clustering, so constructing better feature engineering can improve the performance of the models.
#
# - In Medical Fraud, the fraudulent behavior can also be determined by Percentage of reduplication patients-pharmacy in a month, so if the frequency of patient visits can be taken into account, more feature engineering can be created for modeling.
#
#
# ## Limitation
# - PCA modeling I tried two different packages scikit-learn and pyod. The first package could not give the anomaly score directly, I referred to someone else's code for mathematical calculations and derived a threshold value based on the difference of eigenvalue of the train set then used to predict the number of anomalies in the test set at about 2.7%. The pyod package is more straightforward to derive outlier scores, but requires a good threshold value to get the anomaly score first. My field of knowledge is very limited and I can't say which method is better, but I think both are logically feasible.
#
# - Different aggregation methods are used to obtain different numbers of exceptions, and as the complexity of the aggregation method increases, the number of exceptions obtained increases again. How to determine the boundary threshold more accurately will have a great impact on anomaly clustering.

# %% [markdown]
# # Section 7: Reference

# %% [markdown]
# - Ccsis. (2018,September 4). Anomaly detection--Implementation of PCA algorithm. Jianshu. https://www.jianshu.com/p/e35a47913457
#
# - Dataman, C. K. (2022, January 4). Anomaly Detection with Histogram-based Outlier Score (HBOS). Medium. https://medium.com/dataman-in-ai/anomaly-detection-with-histogram-based-outlier-detection-hbo-bc10ef52f23f
#
# - Dataman, C. K. (2022b, June 24). Dimension Reduction Techniques with Python - Towards Data Science. Medium. https://towardsdatascience.com/dimension-reduction-techniques-with-python-f36ca7009e5c
#
# - Li, S. (2019, January 24). Time series of Price anomaly detection. Medium. https://towardsdatascience.com/time-series-of-price-anomaly-detection-13586cd5ff46
